# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("data.csv", encoding='windows-1252')
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# AGE

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Age"],kde= True,color="#CD1076",linewidth =2)

#sns.set_style("dark")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Gender and Occupation on the basis of Shopping

# %%
# on the basis of gender this plot show the amount of sale of every Occupation
#5555
'''fig=plt.figure(figsize=(15,7))
custom_palette = ["#FF1493", "#00BFFF"]
sns.barplot(x="Occupation",y="Amount",data =df,hue="Gender", palette=custom_palette)
sns.set_style('dark')'''

'''plt.figure(figsize=(15, 7))

custom_palette = ["#FF1493", "#00BFFF"]
ax = sns.barplot(x="Occupation", y="Amount", data=df, hue="Gender", palette=custom_palette)

# Changing x-axis tick label color to white
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')

sns.set_style('dark')

plt.show()'''

'''Top_states = df.groupby(["Occupation"]).sum().sort_values("Amount", ascending=False).head(10) 
Top_states = Top_states[["Amount"]].round(2)
Top_states.reset_index(inplace=True) 
plt.style.use('dark_background')
fig =plt.figure(figsize=(19,7))
plt.title("Top 10 state",fontsize=18)
sns.barplot(Top_states["Occupation"],Top_states["Amount"])#,color='#7FFFD4',edgecolor='Red',linewidth=1)
sns.xlabel("Occupation",fontsize=19)
sns.ylabel("Amount",fontsize=19)
sns.xticks(fontsize=12, rotation=90)
sns.yticks(fontsize=12)
sns.show()'''
Top_occupations = df.groupby(["Occupation"]).sum().sort_values("Amount", ascending=False).head(10)
Top_occupations = Top_occupations[["Amount"]].round(2)
Top_occupations.reset_index(inplace=True)

plt.style.use('dark_background')
plt.figure(figsize=(19, 7))
plt.title("Top 10 Occupations", fontsize=18)
sns.barplot(x="Occupation", y="Amount", data=Top_occupations, palette='viridis')
plt.xlabel("Occupation", fontsize=16)
plt.ylabel("Amount", fontsize=16)
plt.xticks(rotation=45, fontsize=12, ha='right')  # Rotating x-axis labels for better visibility
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# Occupation on the basis of Purchase

# %%
plt.figure(figsize=(19,7))
sns.lineplot(x="Occupation",y="Amount",data =df,color='red')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# Gender Count

# %%
Gender_count=df.Gender.value_counts()
Gender_count
explode =[0,0.1]




fig=plt.figure(figsize=(6,3))
plt.pie(Gender_count.values,labels = Gender_count.index,explode=explode,autopct ='%1.1f%%',shadow =True,wedgeprops={'width':0.3},colors =['#ff9999','#66b3ff'])
plt.show()

# %% [markdown]
# top 10 state that order the most

# %%
Top_states = df.groupby(["State"]).sum().sort_values("Orders", ascending=False).head(10) 
Top_states = Top_states[["Orders"]].round(2)
Top_states.reset_index(inplace=True) 
plt.style.use('dark_background')
plt.figure(figsize=(19,7))
plt.title("Top 10 state",fontsize=18)
plt.bar(Top_states["State"],Top_states["Orders"],color='#7FFFD4',edgecolor='Red',linewidth=1)
plt.xlabel("State",fontsize=19)
plt.ylabel("Order",fontsize=19)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
,#rder wise zone

# %%
Top_Zone= df.groupby(["Zone"]).sum().sort_values("Amount",ascending=False)
Top_Zone= Top_Zone[["Amount"]].astype(int)
Top_Zone.reset_index(inplace=True)

plt.figure(figsize=(10,5))




plt.title("Zone wise Sale",fontsize=18)
plt.bar(Top_Zone["Zone"],Top_Zone["Amount"],color='#FF1493',edgecolor='white',linewidth=1)
plt.xlabel("Zone",fontsize=15,color ='white')  
plt.ylabel("Amount",fontsize=15,color ='white')

plt.show()

# %%
fig=Gender_count=df.Gender.value_counts()
Gender_count
explode =[0,0.1]


fig=plt.pie(Gender_count.values,labels = Gender_count.index,explode=explode,autopct ='%1.1f%%',shadow =True,wedgeprops={'width':0.3},colors =['#ff9999','#66b3ff'])
plt.show(fig)

# %%
#import matplotlib.pyplot as plt

# Sample data for the pie chart
sizes = [69.7, 30.3]
labels = ['F', 'M']

# Create the pie chart
fig, ax = plt.subplots()
wedges, labels, percentages = ax.pie(sizes, labels=labels, autopct='%1.1f%%')

# Add a legend
ax.legend(wedges, labels, title="Gender", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Show the pie chart
plt.show()

# %%
Top_states = df.groupby(["State"]).sum().sort_values("Orders", ascending=False).head(10) 
Top_states = Top_states[["Orders"]].round(2)
Top_states.reset_index(inplace=True) 
plt.style.use('dark_background')
plt.figure(figsize=(19,7))
plt.title("Top 10 state",fontsize=18)
plt.bar(Top_states["State"],Top_states["Orders"],color='#7FFFD4',edgecolor='Red',linewidth=1)
plt.xlabel("State",fontsize=19)
plt.ylabel("Order",fontsize=19)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(15, 9))
custom_palette = ["#FF1493", "#00BFFF"]
ax = sns.barplot(x="Occupation", y="Amount", data=df, hue="Gender", palette=custom_palette)
sns.set_style('dark')
ax.set_xlabel("Occupation", color='white', fontsize=16)  # Setting x-axis label properties
ax.set_ylabel("Amount", color='white', fontsize=16)  # Setting y-axis label properties
ax.tick_params(axis='x', colors='white')  # Setting x-axis tick color to white
ax.tick_params(axis='y', colors='white')  # Setting y-axis tick color to white

# Display the plot in Streamlit

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(15, 9))

# Choose a Seaborn color palette for the bars
custom_palette = sns.color_palette("pastel")  # You can choose any Seaborn palette

ax = sns.barplot(x="Occupation", y="Amount", data=df, hue="Gender", palette=custom_palette)
sns.set_style('dark')

ax.set_xlabel("Occupation", color='white', fontsize=16)
ax.set_ylabel("Amount", color='white', fontsize=16)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Display the plot in Streamlit

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(10, 5))

# Choose colors for the histogram and KDE line
hist_color = "#8B008B"  # Purple color for histogram bars
kde_color = "#FFA500"   # Orange color for KDE line

sns.histplot(df["Age"], kde=True, color=hist_color, kde_kws={'color': kde_color, 'linewidth': 2})
sns.set_style("dark")

# Display the plot in Streamlit
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\COVID\diwali sales.ipynb Cell 23 line 1
#       <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a> hist_color = "#8B008B"  # Purple color for histogram bars
#       <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> kde_color = "#FFA500"   # Orange color for KDE line
# ---> <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> sns.histplot(df["Age"], kde=True, color=hist_color, kde_kws={'color': kde_color, 'linewidth': 2})
#      <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a> sns.set_style("dark")
#
# ...

# %%
# Sample data
# Assuming df contains the data you want to plot

Top_Zone = df.groupby(["Zone"]).sum().sort_values("Amount", ascending=False)
Top_Zone = Top_Zone[["Amount"]].astype(int)
Top_Zone.reset_index(inplace=True)



fig = plt.figure(figsize=(10, 5))
plt.title("Zone-wise Sale", fontsize=18, color='white')
plt.bar(Top_Zone["Zone"], Top_Zone["Amount"], color='#FF1493', edgecolor='red', linewidth=1)
plt.xlabel("Zone", fontsize=15, color='white')
plt.ylabel("Amount", fontsize=15, color='white')
plt.xticks(color='white', rotation=45)  # Rotating x-axis labels for better visibility
plt.yticks(color='white')

# Display the plot in Streamlit
# Out:
# (array([       0.,  5000000., 10000000., 15000000., 20000000., 25000000.,
#         30000000., 35000000., 40000000., 45000000.]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 5000000.0, '0.5'),
#   Text(0, 10000000.0, '1.0'),
#   Text(0, 15000000.0, '1.5'),
#   Text(0, 20000000.0, '2.0'),
#   Text(0, 25000000.0, '2.5'),
#   Text(0, 30000000.0, '3.0'),
#   Text(0, 35000000.0, '3.5'),
#   Text(0, 40000000.0, '4.0'),
#   Text(0, 45000000.0, '4.5')])

# %%
fig=plt.figure(figsize=(10,5))
sns.histplot(df["Age"],color="#CD1076",linewidth =2)
sns.set_style("dark")
#st.write("This Histogram showing different Age of customer.")

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(10, 5))

# Choose colors for the histogram
hist_color = "#20B2AA"  # Light Sea Green color for histogram bars
edge_color = "#008080"  # Teal color for histogram bar edges

sns.histplot(df["Age"], color=hist_color, linewidth=2, edgecolor=edge_color)
sns.set_style("dark")

# Display the plot in Streamlit

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(10, 5))

# Choose colors for the histogram
hist_color = "#20B2AA"  # Light Sea Green color for histogram bars
edge_color = "#008080"  # Teal color for histogram bar edges

fig = sns.histplot(df["Age"], color=hist_color, linewidth=2, edgecolor=edge_color)
sns.set_style("dark")

# Display the plot in Streamlit

# %%
# Sample data
# Assuming df contains the data you want to plot

Top_states = df.groupby(["State"]).sum().sort_values("Orders", ascending=False).head(10)
Top_states = Top_states[["Orders"]].round(2)
Top_states.reset_index(inplace=True)

plt.figure(figsize=(19, 7))

# Choose colors for the bars and edges
bar_color = "#32CD32"  # Lime Green color for bars
edge_color = "#FF4500"  # Orange Red color for bar edges

plt.bar(Top_states["State"], Top_states["Orders"], color=bar_color, edgecolor=edge_color, linewidth=1)
plt.title("Top 10 States by Orders", fontsize=18, color='white')
plt.xlabel("State", fontsize=16, color='white')
plt.ylabel("Orders", fontsize=16, color='white')
plt.xticks(fontsize=12, rotation=90, color='white')
plt.yticks(fontsize=12, color='white')
plt.style.use('dark_background')

plt.show()

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(15, 9))

# Choose a custom color palette
custom_palette = ["#FF69B4", "#00BFFF"]  # Deep Pink and Dodger Blue colors

ax = sns.barplot(x="Occupation", y="Amount", data=df, hue="Gender", palette=custom_palette)
sns.set_style('dark')

# Set tick colors
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Display the plot in Streamlit

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(15, 9))

# Choose a custom color palette
custom_palette = ["#FF69B4", "#00BFFF"]  # Deep Pink and Dodger Blue colors for the bars

ax = sns.barplot(x="Occupation", y="Amount", data=df, hue="Gender", palette=custom_palette)
sns.set_style('dark')

# Set background color
background_color = "black"  # Dark Slate Gray background color
ax.set_facecolor(background_color)

# Set tick colors
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')

# Set grid color
ax.grid(color='#2B60DE', linestyle='--', linewidth=0.5, axis='y', alpha=0.7)

# Set legend color
legend = ax.legend()
legend.set_title("Gender")
for text in legend.get_texts():
    text.set_color("white")

# Set title and labels color
ax.set_title("Occupation-wise Amount by Gender", fontsize=18, color='white')
ax.set_xlabel("Occupation", fontsize=16, color='white')
ax.set_ylabel("Amount", fontsize=16, color='white')

# Display the plot in Streamlit
# Out:
# Text(0, 0.5, 'Amount')

# %%
# Sample data
# Assuming df contains the data you want to plot

plt.figure(figsize=(15, 9))

# Choose a custom color palette
custom_palette = ["#FF69B4", "#00BFFF"]  # Deep Pink and Dodger Blue colors for the bars

ax = sns.barplot(x="Occupation", y="Amount", data=df, hue="Gender", palette=custom_palette)
sns.set_style('dark')

# Set background color
background_color = "#34495E"  # Midnight Blue background color
ax.set_facecolor(background_color)

# Set tick colors
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set grid color
ax.grid(color='white', linestyle='--', linewidth=0.5, axis='y', alpha=0.7)

# Set legend color
legend = ax.legend()
legend.set_title("Gender")
for text in legend.get_texts():
    text.set_color("white")

# Set title and labels color
ax.set_title("Occupation-wise Amount by Gender", fontsize=18, color='white')
ax.set_xlabel("Occupation", fontsize=16, color='white')
ax.set_ylabel("Amount", fontsize=16, color='white')

# Display the plot in Streamlit
# Out:
# Text(0, 0.5, 'Amount')

# %%
# Sample data
# Assuming df contains the data you want to plot

Top_Zone = df.groupby(["Zone"]).sum().sort_values("Amount", ascending=False)
Top_Zone = Top_Zone[["Amount"]].astype(int)
Top_Zone.reset_index(inplace=True)color = "#1A535C"  # Dark Cyan color for bar edges

plt.bar(Top_Zone["Zone"], Top_Zone["Amount"], color=bar_color, edgecolor=edge_color, linewidth=1)
plt.title("Zone-wise Sales", fontsize=18, color='white')
plt.xlabel("Zone", fontsize=15, color='white')
plt.ylabel("Amount", fontsize=15, color='white')
plt.xticks(color='white', rotation=45)  # Rotating x-axis labels for better visibility
plt.yticks(color='white')

plt.style.use('dark_background')
plt.show()
# Out:
#   Cell In[1], line 6
#     Top_Zone.reset_index(inplace=True)color = "#1A535C"  # Dark Cyan color for bar edges
#                                       ^
# SyntaxError: invalid syntax

# %%
# Sample data
# Assuming Top_Zone contains the data you want to plot

fig = plt.figure(figsize=(10, 5), facecolor='black')  # Set the background color to black
plt.title("Zone wise Sale", fontsize=18, color='white')
plt.bar(Top_Zone["Zone"], Top_Zone["Amount"], color='#FF1493', edgecolor='Red', linewidth=1)
plt.xlabel("Zone", fontsize=15, color='white')
plt.ylabel("Amount", fontsize=15, color='white')
plt.xticks(color='white', rotation=45)  # Rotating x-axis labels for better visibility
plt.yticks(color='white')
# Out:
# (array([       0.,  5000000., 10000000., 15000000., 20000000., 25000000.,
#         30000000., 35000000., 40000000., 45000000.]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 5000000.0, '0.5'),
#   Text(0, 10000000.0, '1.0'),
#   Text(0, 15000000.0, '1.5'),
#   Text(0, 20000000.0, '2.0'),
#   Text(0, 25000000.0, '2.5'),
#   Text(0, 30000000.0, '3.0'),
#   Text(0, 35000000.0, '3.5'),
#   Text(0, 40000000.0, '4.0'),
#   Text(0, 45000000.0, '4.5')])

# %%
# Sample data
# Assuming Top_Zone contains the data you want to plot

# Group and prepare data (Top_Zone)
Top_Zone = df.groupby(["Zone"]).sum().sort_values("Amount", ascending=False)
Top_Zone = Top_Zone[["Amount"]].astype(int)
Top_Zone.reset_index(inplace=True)

# Create the plot with a black background
fig, ax = plt.subplots(figsize=(10, 5))
fig.patch.set_facecolor('black')  # Set the figure background color to black
ax.set_facecolor('black')  # Set the axis background color to black

# Plotting the data
plt.title("Zone wise Sale", fontsize=18, color='white')
plt.bar(Top_Zone["Zone"], Top_Zone["Amount"], color='#FF1493', edgecolor='Red', linewidth=1)
plt.xlabel("Zone", fontsize=15, color='white')  
plt.ylabel("Amount", fontsize=15, color='white')

# Set x and y tick colors to white
plt.xticks(color='white', rotation=45)  
plt.yticks(color='white')

# Show the plot
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
sns.lineplot(x="Occupation", y="Amount", data=df, color='red')
plt.title("Occupation-wise Sales", fontsize=18)
plt.xlabel("Occupation", fontsize=15)
plt.ylabel("Amount", fontsize=15)
plt.xticks(rotation=45)  # Rotating x-axis labels for better visibility
plt.grid(True)  # Add gridlines for better readability

plt.show()

# %%
fig=plt.figure(figsize=(10,5))
sns.lineplot(x="Occupation",y="Amount",data =df,color='red')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
# Sample data
# Assuming Gender_count and explode are defined in your code
# Gender_count = df['Gender'].value_counts()
# explode = [0, 0.1]

fig, ax = plt.subplots(figsize=(9, 5))

# Plotting the pie chart
ax.pie(Gender_count.values, labels=Gender_count.index, explode=explode, autopct='%1.1f%%', shadow=True, wedgeprops={'width': 0.3},
       colors=['#ff9999', '#66b3ff'])

# Setting the title (optional)
ax.set_title("Gender Distribution", fontsize=18)

# Display the plot in Streamlit
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
# Sample data
# Assuming Gender_count and explode are defined in your code
# Gender_count = df['Gender'].value_counts()
# explode = [0, 0.1]

# Define custom colors
colors = ['#000000', '#66B3FF']

fig, ax = plt.subplots(figsize=(9, 5))

# Plotting the pie chart with custom colors
ax.pie(Gender_count.values, labels=Gender_count.index, explode=explode, autopct='%1.1f%%', shadow=True, wedgeprops={'width': 0.3},
       colors=colors)

# Setting the title (optional)
ax.set_title("Gender Distribution", fontsize=18, color='#333333')  # Title color can be adjusted here

# Display the plot in Streamli
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
# Sample data
# Assuming Gender_count and explode are defined in your code
# Gender_count = df['Gender'].value_counts()
# explode = [0, 0.1]

# Define a pleasing color palette
colors = ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f']

fig, ax = plt.subplots(figsize=(9, 5))

# Plotting the pie chart with custom colors
wedges, texts, autotexts = ax.pie(Gender_count.values, labels=Gender_count.index, explode=explode, autopct='%1.1f%%', shadow=True, wedgeprops={'width': 0.3},
       colors=colors, startangle=90)  # You can change the startangle for a different rotation of the chart

# Setting the title (optional)
#ax.set_title("Gender Distribution", fontsize=18, color='#333333')  # Title color can be adjusted here

# Customize the text properties
for text, autotext in zip(texts, autotexts):
    text.set(color='white', fontweight='bold')  # Color and font weight of category labels
    autotext.set(color='white', fontweight='bold')  # Color and font weight of percentage labels

# Display the plot in Streamlit

# %%
# Sample data
# Assuming Gender_count and explode are defined in your code
# Gender_count = df['Gender'].value_counts()
# explode = [0, 0.1]

# Define a pleasing color palette
colors = ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854', '#ffd92f']

fig, ax = plt.subplots(figsize=(9, 5))
fig.patch.set_facecolor('#000000')  # Set the figure background color to black
ax.set_facecolor('#000000')  # Set the axis background color to black

# Plotting the pie chart with custom colors
wedges, texts, autotexts = ax.pie(Gender_count.values, labels=Gender_count.index, explode=explode, autopct='%1.1f%%', shadow=True, wedgeprops={'width': 0.3},
       colors=colors, startangle=90)  # You can change the startangle for a different rotation of the chart

# Setting the title (optional)
#ax.set_title("Gender Distribution", fontsize=18, color='white')  # Title color can be adjusted here

# Customize the text properties
for text, autotext in zip(texts, autotexts):
    text.set(color='white', fontweight='bold')  # Color and font weight of category labels
    autotext.set(color='white', fontweight='bold')  # Color and font weight of percentage labels

# Display the plot in Streamlit

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\COVID\diwali sales.ipynb Cell 42 line 1
#      <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X56sZmlsZQ%3D%3D?line=13'>14</a> ax.set_facecolor('#000000')  # Set the axis background color to black
#      <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X56sZmlsZQ%3D%3D?line=15'>16</a> # Plotting the scatter plot with custom colors
# ---> <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X56sZmlsZQ%3D%3D?line=16'>17</a> ax.scatter(range(len(Gender_count)), Gender_count.values, color=colors)
#      <a href='vscode-notebook-cell:/e%3A/COVID/diwali%20sales.ipynb#X56sZmlsZQ%3D%3D?line=18'>19</a> # Setting the title (optional)
# ...
